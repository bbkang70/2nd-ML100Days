# %% [markdown]
# 第一題：我選擇的資料為Digit Recognizer(https://www.kaggle.com/c/digit-recognizer/overview/evaluation)
#
#     1.AI 入門都會用這個資料 容易上手
#
#     2.手寫數字的資料集
#
#     3.28 pixels X 28 pixels 的圖片集
#
#     4.辨識數字
#
# 第二題
#
#     核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     1.我的假設為：要提升業績，先提高駕駛行為，讓消費者信任這項服務，而繼續使用並介紹他人使用。
#
#     2.資料從何而來：請客戶每次結束一次的旅程，填寫對這次駕駛的評分
#
#     3.蒐集而來的資料型態為何:結構化 表單
#
#     4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)：以評分跟業績來驗證是否高的評分會使業績成長，反之下降。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(a, b):
    return (pow(a - b, 2)).mean()

def mean_absolute_error(a, b):
    return sum(abs(a - b)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 220.446
# The Mean absolute error is 11.488
